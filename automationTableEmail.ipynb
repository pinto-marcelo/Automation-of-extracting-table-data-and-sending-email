# %%
# !pip3 install pyautogui
# !pip3 install pyperclip
# !pip3 install pandas

import pyautogui
import pyperclip
import time
import pandas

# %%
pyautogui.PAUSE = 1

#pyautogui.press("win")
#pyautogui.write("chrome")
#pyautogui.press("enter")


pyautogui.hotkey("ctrl", "t") #conjunto de teclas = hotkey

#file name and path:
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(2)

pyautogui.click(x=360, y=263, clicks=2)

#pyautogui.click(x=360, y=263, button="right")

#pyautogui.press("enter")

#scroll:
time.sleep(1)

pyautogui.click(x=434, y=258, button="right")

time.sleep(2)

pyautogui.click(x=561, y=636) #fazer download

time.sleep(3)
#pyautogui.hotkey("up", "up", "up", "enter")

tabela = pandas.read_excel(r"/home/marcelo-pinto/Downloads/Vendas - Dez.xlsx")
#pd.read_csv
#pd.read_html
#pd.read_sql
#pandas = pandas. + 'tab': abre as opções
display(tabela)

#cálculo faturamento e qtd:
faturamento = tabela["Valor Final"].sum()

quantidade = tabela["Quantidade"].sum()

display(faturamento)

display(quantidade)

# %%
#email:

pyautogui.hotkey("ctrl", "t") 
pyperclip.copy("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=84, y=171)

pyautogui.write("pythonimpressionador@gmail.com")
pyautogui.press("tab")
pyautogui.press("tab")

pyperclip.copy("Relatório de vendas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

#texto
texto = f""" Prezados, bom dia
O faturamento do último trimestre foi de:R$ {faturamento:,.2f}
A quantidade de produtos vendidos foi de:R$ {quantidade:,}

Atenciosamente,

Marcelo
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("ctrl", "enter")

# %%
time.sleep(5)
pyautogui.position()
